# %%
import pandas as pd
import os
from tqdm import tqdm
import warnings

warnings.filterwarnings('ignore')

# %%
list_data = os.listdir('../data/')

# %%
df = pd.DataFrame()

for file in tqdm(list_data):

    if file.endswith('.csv'):
        file_path = os.path.join('../data/', file)
    
        dataset = pd.read_csv(file_path, sep=';', encoding='latin-1')
        dataset = dataset.loc[:, ~dataset.columns.str.contains('^Unnamed')]
        dataset = dataset.loc[:, ~dataset.columns.str.contains('Codigo CPC')]
        dataset.columns = ['mercado', 'fecha', 'cod_dpto', 'cod_mun',
                        'nom_dpto', 'nom_mun', 'grupo', 'alimento', 
                        'cantidad']
    
        df = pd.concat([df, dataset])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:15<00:00,  1.02it/s]

# %%
df['alimento'] = df['alimento'].str.upper()

# %%
df['fecha'] = pd.to_datetime(df['fecha'])
df['anio'] = df['fecha'].dt.year
df['mes'] = df['fecha'].dt.month
df['dia'] = df['fecha'].dt.day

# %%
df['cantidad'] = df['cantidad'].str.replace(',', '.')
df['cantidad'] = df['cantidad'].astype('float')

# %%
df['cod_dpto'] = df['cod_dpto'].str.extract('(\d+)', expand=False)
df['cod_mun'] = df['cod_mun'].str.extract('(\d+)', expand=False)

# %%
df['nom_mun'] = df['nom_mun'] + ' (' + df['nom_dpto'] + ')'

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                              mercado      fecha cod_dpto cod_mun  \
# 0       Barranquilla, Barranquillita 2019-01-07       76   76400
# 1       Barranquilla, Barranquillita 2019-01-07       76   76400
# 2       Barranquilla, Barranquillita 2019-01-07       76   76400
# 3       Barranquilla, Barranquillita 2019-01-07       76   76400
# 4       Barranquilla, Barranquillita 2019-01-07       76   76400
# ...                              ...        ...      ...     ...
# 923318            Villavicencio, CAV 2022-06-30       25   25178
# 923319            Villavicencio, CAV 2022-06-30       25   25178
# 923320            Villavicencio, CAV 2022-06-30       25   25178
# 923321            Villavicencio, CAV 2022-06-30       25   25269
# 923322            Villavicencio, CAV 2022-06-30       15   15176
#
#                nom_dpto                     nom_mun  \
# 0       VALLE DEL CAUCA  LA UNIÓN (VALLE DEL CAUCA)
# 1       VALLE DEL CAUCA  LA UNIÓN (VALLE DEL CAUCA)
# 2       VALLE DEL CAUCA  LA UNIÓN (VALLE DEL CAUCA)
# 3       VALLE DEL CAUCA  LA UNIÓN (VALLE DEL CAUCA)
# 4       VALLE DEL CAUCA  LA UNIÓN (VALLE DEL CAUCA)
# ...                 ...                         ...
# 923318     CUNDINAMARCA     CHIPAQUE (CUNDINAMARCA)
# 923319     CUNDINAMARCA     CHIPAQUE (CUNDINAMARCA)
# 923320     CUNDINAMARCA     CHIPAQUE (CUNDINAMARCA)
# 923321     CUNDINAMARCA   FACATATIVÁ (CUNDINAMARCA)
# 923322           BOYACÁ       CHIQUINQUIRÁ (BOYACÁ)
#
#                                 grupo            alimento  cantidad    anio  \
# 0                              FRUTAS        UVA NACIONAL     162.0  2019.0
# 1                              FRUTAS            MARACUYÁ    2200.0  2019.0
# 2                              FRUTAS  AGUACATE PAPELILLO     200.0  2019.0
# 3                              FRUTAS        GUAYABA PERA    2400.0  2019.0
# 4               VERDURAS Y HORTALIZAS            PIMENTÓN    1944.0  2019.0
# ...                               ...                 ...       ...     ...
# 923318  TUBERCULOS, RAICES Y PLATANOS       PAPA SUPERIOR    4000.0  2022.0
# 923319          VERDURAS Y HORTALIZAS            CILANTRO    1000.0  2022.0
# 923320  TUBERCULOS, RAICES Y PLATANOS        PAPA CRIOLLA    2500.0  2022.0
# 923321                         FRUTAS               FRESA    1040.0  2022.0
# 923322                         FRUTAS                MORA     700.0  2022.0
#
#         mes   dia
# 0       1.0   7.0
# 1       1.0   7.0
# 2       1.0   7.0
# 3       1.0   7.0
# 4       1.0   7.0
# ...     ...   ...
# 923318  6.0  30.0
# 923319  6.0  30.0
# 923320  6.0  30.0
# 923321  6.0  30.0
# 923322  6.0  30.0
#
# [10442949 rows x 12 columns]

# %%
df.reset_index(drop=True, inplace=True)
df.to_feather('../data/data.feather')
